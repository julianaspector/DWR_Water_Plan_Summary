# %%
import pandas as pd # call pandas
# type path to file with forward slashes
excel_file = 'C:/Users/JSpector/Documents/Projects/California Water Plan Use Project/Updated DWR Final/DWR Updated Water Use.xlsx'
# read in desired sheet
sheet_name = '2005_2010_Averages'
df = pd.read_excel(excel_file, sheet_name, index_col = 18)
# preview first five rows and all columns
df.head()
# array of relevant planning areas
relevant_pareas = [501, 502, 503, 504, 505, 506, 507, 508, 509, 511, 510, 602, 603, 604, 201, 202, 601, 605, 606, 607, 
                  608, 609, 610, 701, 702, 703, 704, 705, 706, 707, 708, 709, 710, 301, 302, 1001, 1002, 1003, 1004,
                  1005, 1006, 901, 902, 903, 904, 905, 401, 402, 403, 404]
# name the lists
list_names = ['gw_ag', 'gw_urban', 'gw_mw', 'total_supply_ag', 'total_supply_urban', 'total_supply_mw']
# create an empty dictionary
dct_lists = {}
# create a list for each name
for i in list_names:
    dct_lists[i]=[]
# select the relevant data from each column and append to separate lists
for x in relevant_pareas:
        dct_lists['gw_ag'].append(df.loc[x,'Total GW AG.1'])
        dct_lists['gw_urban'].append(df.loc[x, 'Total GW Urban.1'])
        dct_lists['gw_mw'].append(df.loc[x, 'Total GW MW.1'])
        dct_lists['total_supply_ag'].append(df.loc[x, 'Total Supply AG'])
        dct_lists['total_supply_urban'].append(df.loc[x, 'Total Supply Urban'])
        dct_lists['total_supply_mw'].append(df.loc[x, 'Total Supply MW'])
# Write data to output file
area_names = ['sac_river_gw_ag', 'sac_river_gw_urban', 'sac_river_gw_mw', 
              'sac_river_total_supply_ag', 'sac_river_total_supply_urban', 'sac_river_total_supply_mw',
              'delta_gw_ag', 'delta_gw_urban', 'delta_gw_mw', 
              'delta_total_supply_ag', 'delta_total_supply_urban', 'delta_total_supply_mw',
              'delta_eastside_gw_ag', 'delta_eastside_gw_urban', 'delta_eastside_gw_mw', 
              'delta_eastside_total_supply_ag', 'delta_eastside_total_supply_urban', 'delta_eastside_total_supply_mw',
              'sfbay_total_supply_ag', 'sfbay_total_supply_urban', 'sfbay_total_supply_mw',
              'sfbay_gw_ag', 'sfbay_gw_urban', 'sfbay_gw_mw', 
              'sfbay_total_supply_ag', 'sfbay_total_supply_urban', 'sfbay_total_supply_mw',
              'sj_valley_gw_ag', 'sj_valley_gw_urban', 'sj_valley_gw_mw', 
              'sj_valley_total_supply_ag', 'sj_valley_total_supply_urban', 'sj_valley_total_supply_mw',
              'cc_gw_ag', 'cc_gw_urban', 'cc_gw_mw', 
              'cc_total_supply_ag', 'cc_total_supply_urban', 'cc_total_supply_mw',
              'socal_gw_ag', 'socal_gw_urban', 'socal_gw_mw', 
              'socal_total_supply_ag', 'socal_total_supply_urban', 'socal_total_supply_mw']
# create an empty dictionary
area_dict = {}
# create a list for each name
for j in area_names:
    area_dict[j]=[]
    
for n in range(10):
    area_dict['sac_river_gw_ag'].append(dct_lists['gw_ag'][n])
    area_dict['sac_river_gw_urban'].append(dct_lists['gw_urban'][n])
    area_dict['sac_river_gw_mw'].append(dct_lists['gw_mw'][n])
    area_dict['sac_river_total_supply_ag'].append(dct_lists['total_supply_ag'][n])
    area_dict['sac_river_total_supply_urban'].append(dct_lists['total_supply_urban'][n])
    area_dict['sac_river_total_supply_mw'].append(dct_lists['total_supply_mw'][n])
    
for n in range(10,12):
    area_dict['delta_gw_ag'].append(dct_lists['gw_ag'][n])
    area_dict['delta_gw_urban'].append(dct_lists['gw_urban'][n])
    area_dict['delta_gw_mw'].append(dct_lists['gw_mw'][n])
    area_dict['delta_total_supply_ag'].append(dct_lists['total_supply_ag'][n])
    area_dict['delta_total_supply_urban'].append(dct_lists['total_supply_urban'][n])
    area_dict['delta_total_supply_mw'].append(dct_lists['total_supply_mw'][n])
    
for n in range(12,14):
    area_dict['delta_eastside_gw_ag'].append(dct_lists['gw_ag'][n])
    area_dict['delta_eastside_gw_urban'].append(dct_lists['gw_urban'][n])
    area_dict['delta_eastside_gw_mw'].append(dct_lists['gw_mw'][n])
    area_dict['delta_eastside_total_supply_ag'].append(dct_lists['total_supply_ag'][n])
    area_dict['delta_eastside_total_supply_urban'].append(dct_lists['total_supply_urban'][n])
    area_dict['delta_eastside_total_supply_mw'].append(dct_lists['total_supply_mw'][n])

for n in range(14,16):
    area_dict['sfbay_gw_ag'].append(dct_lists['gw_ag'][n])
    area_dict['sfbay_gw_urban'].append(dct_lists['gw_urban'][n])
    area_dict['sfbay_gw_mw'].append(dct_lists['gw_mw'][n])
    area_dict['sfbay_total_supply_ag'].append(dct_lists['total_supply_ag'][n])
    area_dict['sfbay_total_supply_urban'].append(dct_lists['total_supply_urban'][n])
    area_dict['sfbay_total_supply_mw'].append(dct_lists['total_supply_mw'][n])    
    
for n in range(16,33):
    area_dict['sj_valley_gw_ag'].append(dct_lists['gw_ag'][n])
    area_dict['sj_valley_gw_urban'].append(dct_lists['gw_urban'][n])
    area_dict['sj_valley_gw_mw'].append(dct_lists['gw_mw'][n])
    area_dict['sj_valley_gw_mw'].append(dct_lists['gw_mw'][n])
    area_dict['sj_valley_total_supply_ag'].append(dct_lists['total_supply_ag'][n])
    area_dict['sj_valley_total_supply_urban'].append(dct_lists['total_supply_urban'][n])
    area_dict['sj_valley_total_supply_mw'].append(dct_lists['total_supply_mw'][n])
    
for n in range(33,35):
    area_dict['cc_gw_ag'].append(dct_lists['gw_ag'][n])
    area_dict['cc_gw_urban'].append(dct_lists['gw_urban'][n])
    area_dict['cc_gw_mw'].append(dct_lists['gw_mw'][n])
    area_dict['cc_total_supply_ag'].append(dct_lists['total_supply_ag'][n])
    area_dict['cc_total_supply_urban'].append(dct_lists['total_supply_urban'][n])
    area_dict['cc_total_supply_mw'].append(dct_lists['total_supply_mw'][n])
    
for n in range(35,50):
    area_dict['socal_gw_ag'].append(dct_lists['gw_ag'][n])
    area_dict['socal_gw_urban'].append(dct_lists['gw_urban'][n])
    area_dict['socal_gw_mw'].append(dct_lists['gw_mw'][n])
    area_dict['socal_total_supply_ag'].append(dct_lists['total_supply_ag'][n])
    area_dict['socal_total_supply_urban'].append(dct_lists['total_supply_urban'][n])
    area_dict['socal_total_supply_mw'].append(dct_lists['total_supply_mw'][n])

   

#area_dict['sac_river_gw_ag'].to_excel('C:/Users/JSpector/Documents/Projects/California Water Plan Use Project/Updated DWR Final/Write_Data', sheetname = 'Summary_Sheet', index= false, startcol = 3, startrow = 3)
# Out:
#             0
# 0    0.000000
# 1    0.000000
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5   30.300000
# 6    0.000000
# 7    0.000000
# 8    0.000000
# 9    0.000000
# 10   0.000000
# 11   0.000000
# 12  26.800000
# 13   5.116667
# 14   0.166667
